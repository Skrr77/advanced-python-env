# %%
# !pip install pandas

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [19, 22, 21, 18, 23],
    'Score': [85, 78, 92, 65, 88]
}
df = pd.DataFrame(data)

# %%
df.head(3)

# %%
df.describe()

# %%
df['Score'].mean()

# %%
df[df['Age'] > 20]
# Out:
#       Name  Age  Score
# 1      Bob   22     78
# 2  Charlie   21     92
# 4      Eva   23     88

# %%
df[df['Score'] > 80]
# Out:
#       Name  Age  Score
# 0    Alice   19     85
# 2  Charlie   21     92
# 4      Eva   23     88
